# %%
from MultipleFunctions import MultipleFunctions

# %%
MultipleFunctions.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech
# NLP

# %%
MultipleFunctions.OddEven()
# Out:
# Enter number? : 65
# 65 is  odd number

# %%
MultipleFunctions.Eligible()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-ea5b8b8af1ee> in <module>
# ----> 1 MultipleFunctions.Eligible()
#
# AttributeError: type object 'MultipleFunctions' has no attribute 'Eligible'

# %%
MultipleFunctions.percentage()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f2726e3e3cd1> in <module>
# ----> 1 MultipleFunctions.percentage()
#
# NameError: name 'MultipleFunctions' is not defined
